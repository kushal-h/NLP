# %% [markdown]
# <a href="https://colab.research.google.com/github/kushal-h/NLP/blob/main/NER/NER_Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy 
import spacy.displacy as displacy

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp("As soon as joe biden came into office, he signed executive orders that guaranteed we would have a migrant crisis on our southwest border. By reversing a raft of Trump-era policies that had managed to control illegal immigration amid a worsening pandemic, Biden effectively opened the borders, sending the message to would-be asylum seekers that if they could manage to get across the Rio Grande with at least one child in tow, they could stay — and if they sent their child alone, he or she would definitely stay.")
for ent in doc.ents:
  print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# joe biden 11 20 PERSON
# Trump 161 166 PERSON
# Biden 255 260 ORG
# Rio Grande 384 394 PERSON
# at least one 400 412 CARDINAL

# %%
displacy.render(doc,jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As soon as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     joe biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  came into office, he signed executive orders that guaranteed we would have a migrant crisis on our southwest border. By reversing a raft of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...

# %%
displacy.render(doc, jupyter=True,style='dep', options={'distance': 70})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7f6166d0caf546a598b1bbcf1aea07d8-0" class="displacy" width="6280" height="522.0" direction="ltr" style="max-width: none; height: 522.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">soon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
# ...

# %% [markdown]
# ### Bio-Medical

# %%
# !pip install spacy
# !pip install scispacy
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz
# Out:
# ...
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz (17.0 MB)
# ...

# %%
import scispacy
import spacy
import en_core_sci_sm   #The model we are going to use
from spacy import displacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.umls_linking import UmlsEntityLinker
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:718: UserWarning: [W094] Model 'en_core_sci_sm' (0.2.4) specifies an under-constrained spaCy version requirement: >=2.2.1. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.0.7,<3.1.0
#   warnings.warn(warn_msg)

# %%
nlp = spacy.load("en_core_sci_sm")   #Define the pre-trained model.
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:718: UserWarning: [W094] Model 'en_core_sci_sm' (0.2.4) specifies an under-constrained spaCy version requirement: >=2.2.1. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.0.7,<3.1.0
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-a79e7f61268f> in <module>()
# ----> 1 nlp = spacy.load("en_core_sci_sm")   #Define the pre-trained model.
#
# /usr/local/lib/python3.7/dist-packages/spacy/__init__.py in load(name, vocab, disable, exclude, config)
#      49     """
#      50     return util.load_model(
# ...

# %%
text = '''Myeloid derived suppressor cells (MDSC) are immature 
          myeloid cells with immunosuppressive activity. 
          They accumulate in tumor-bearing mice and humans 
          with different types of cancer, including hepatocellular 
          carcinoma (HCC).'''

# %%
nlp = en_core_sci_sm.load()
# doc = nlp(text)
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:718: UserWarning: [W094] Model 'en_core_sci_sm' (0.2.4) specifies an under-constrained spaCy version requirement: >=2.2.1. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.0.7,<3.1.0
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-5381e69e9a41> in <module>()
# ----> 1 nlp = en_core_sci_sm.load()
#       2 # doc = nlp(text)
#
# /usr/local/lib/python3.7/dist-packages/en_core_sci_sm/__init__.py in load(**overrides)
#       8
#       9 def load(**overrides):
# ---> 10     nlp = load_model_from_init_py(__file__, **overrides)
#      11     return nlp
#
# ...

# %%
print(doc.ents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1ead68df7255> in <module>()
# ----> 1 print(doc.ents)
#
# NameError: name 'doc' is not defined
